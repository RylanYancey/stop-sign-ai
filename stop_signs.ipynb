# %%
# You may need to run subsequent cells before running this cell

# %load_ext tensorboard

import tensorflow as tf
from keras import Model
from keras.callbacks import EarlyStopping
from keras.optimizers import *
import datetime

print(tf.version.VERSION)

print('Loading Model...')

model: Model = create_model()
model.summary()

print('Model Loaded Successfully')

print('Loading data...')

train_labels, train_images, filenames = load('train')

train_labels = tf.constant(train_labels)
train_images = tf.constant(train_images)

print('Data loaded successfully')

model.compile(
    optimizer='adam',
    loss='binary_crossentropy', 
    metrics=['accuracy']
)

# Configure Tensorboard
log_dir = "logs/fit/" + "latest" #datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

early_stop_callback = EarlyStopping(monitor="accuracy", patience=3)

# Actual Training Occurs Here
model.fit(
    train_images, 
    train_labels,
    epochs=60, 
    batch_size=25, 
    # 20% of the dataset is set aside for validation
    # validation_split=0.2, 
    callbacks=[
        tensorboard_callback,
        # early_stop_callback,
    ],
)

# Evaluate the Model to Print the Accuracy
loss, acc = model.evaluate(train_images, train_labels, batch_size=10)

model.save('models/initial.keras')

print(f'Accuracy: {acc}')

# %tensorboard --logdir logs/fit
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# 2.15.0
# Loading Model...
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_rotation_4 (RandomR  (None, 244, 244, 3)       0
#  otation)
#
#  random_flip_2 (RandomFlip)  (None, 244, 244, 3)       0
#
#  conv2d_100 (Conv2D)         (None, 242, 242, 12)      336
#
#  max_pooling2d_100 (MaxPool  (None, 121, 121, 12)      0
#  ing2D)
#
#  conv2d_101 (Conv2D)         (None, 119, 119, 12)      1308
#
#  max_pooling2d_101 (MaxPool  (None, 59, 59, 12)        0
#  ing2D)
#
#  conv2d_102 (Conv2D)         (None, 57, 57, 12)        1308
#
#  max_pooling2d_102 (MaxPool  (None, 28, 28, 12)        0
#  ing2D)
#
#  conv2d_103 (Conv2D)         (None, 26, 26, 12)        1308
#
#  max_pooling2d_103 (MaxPool  (None, 13, 13, 12)        0
#  ing2D)
#
#  conv2d_104 (Conv2D)         (None, 11, 11, 12)        1308
#
#  max_pooling2d_104 (MaxPool  (None, 5, 5, 12)          0
#  ing2D)
#
#  flatten_22 (Flatten)        (None, 300)               0
#
#  dropout_44 (Dropout)        (None, 300)               0
#
#  batch_normalization_22 (Ba  (None, 300)               1200
#  tchNormalization)
#
#  dense_44 (Dense)            (None, 8)                 2408
#
#  dropout_45 (Dropout)        (None, 8)                 0
#
#  dense_45 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 9185 (35.88 KB)
# Trainable params: 8585 (33.54 KB)
# Non-trainable params: 600 (2.34 KB)
# _________________________________________________________________
# Model Loaded Successfully
# Loading data...
# 2024-02-19 18:28:51.591503: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 2024-02-19 18:28:51.823457: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# 2024-02-19 18:28:52.035205: W tensorflow/core/lib/png/png_io.cc:88] PNG warning: iCCP: known incorrect sRGB profile
# Data loaded successfully
# Epoch 1/60
# 12/12 [==============================] - 2s 35ms/step - loss: 0.9249 - accuracy: 0.5250
# Epoch 2/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.8857 - accuracy: 0.5000
# Epoch 3/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.8388 - accuracy: 0.5321
# Epoch 4/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.8382 - accuracy: 0.4929
# Epoch 5/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.8059 - accuracy: 0.5357
# Epoch 6/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.7687 - accuracy: 0.5607
# Epoch 7/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.7729 - accuracy: 0.5286
# Epoch 8/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.7524 - accuracy: 0.5536
# Epoch 9/60
# 12/12 [==============================] - 0s 34ms/step - loss: 0.7833 - accuracy: 0.4893
# Epoch 10/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.7684 - accuracy: 0.5214
# Epoch 11/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.7368 - accuracy: 0.5607
# Epoch 12/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.7317 - accuracy: 0.5536
# Epoch 13/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.7286 - accuracy: 0.5679
# Epoch 14/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.7227 - accuracy: 0.5464
# Epoch 15/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.6789 - accuracy: 0.6393
# Epoch 16/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.6789 - accuracy: 0.6250
# Epoch 17/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.6691 - accuracy: 0.6393
# Epoch 18/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.6466 - accuracy: 0.6536
# Epoch 19/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.6509 - accuracy: 0.6643
# Epoch 20/60
# 12/12 [==============================] - 0s 36ms/step - loss: 0.6771 - accuracy: 0.6214
# Epoch 21/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.6753 - accuracy: 0.6429
# Epoch 22/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.6445 - accuracy: 0.6643
# Epoch 23/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.6326 - accuracy: 0.7000
# Epoch 24/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.6468 - accuracy: 0.6321
# Epoch 25/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.6231 - accuracy: 0.6786
# Epoch 26/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.6275 - accuracy: 0.6500
# Epoch 27/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.6030 - accuracy: 0.7000
# Epoch 28/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.6048 - accuracy: 0.6893
# Epoch 29/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5920 - accuracy: 0.7357
# Epoch 30/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.6029 - accuracy: 0.6893
# Epoch 31/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5929 - accuracy: 0.6964
# Epoch 32/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5891 - accuracy: 0.7286
# Epoch 33/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5864 - accuracy: 0.7214
# Epoch 34/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5641 - accuracy: 0.7536
# Epoch 35/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5884 - accuracy: 0.7429
# Epoch 36/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5663 - accuracy: 0.7143
# Epoch 37/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5597 - accuracy: 0.7357
# Epoch 38/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5683 - accuracy: 0.7357
# Epoch 39/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5519 - accuracy: 0.7714
# Epoch 40/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5475 - accuracy: 0.7536
# Epoch 41/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5587 - accuracy: 0.7536
# Epoch 42/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5500 - accuracy: 0.7571
# Epoch 43/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5309 - accuracy: 0.7821
# Epoch 44/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5060 - accuracy: 0.8000
# Epoch 45/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5085 - accuracy: 0.7893
# Epoch 46/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5429 - accuracy: 0.7750
# Epoch 47/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5272 - accuracy: 0.7714
# Epoch 48/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5327 - accuracy: 0.7500
# Epoch 49/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.4935 - accuracy: 0.8036
# Epoch 50/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5080 - accuracy: 0.8000
# Epoch 51/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5349 - accuracy: 0.7714
# Epoch 52/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5045 - accuracy: 0.8071
# Epoch 53/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5174 - accuracy: 0.8000
# Epoch 54/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5113 - accuracy: 0.7714
# Epoch 55/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5272 - accuracy: 0.7643
# Epoch 56/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5449 - accuracy: 0.7571
# Epoch 57/60
# 12/12 [==============================] - 0s 33ms/step - loss: 0.5384 - accuracy: 0.7750
# Epoch 58/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5215 - accuracy: 0.7643
# Epoch 59/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5185 - accuracy: 0.7821
# Epoch 60/60
# 12/12 [==============================] - 0s 32ms/step - loss: 0.5109 - accuracy: 0.8036
# 28/28 [==============================] - 0s 5ms/step - loss: 0.4927 - accuracy: 0.8179
# Accuracy: 0.8178571462631226
# Reusing TensorBoard on port 6006 (pid 38696), started 2:17:34 ago. (Use '!kill 38696' to kill it.)
#       <iframe id="tensorboard-frame-5e3a767cd53eb5e5" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5e3a767cd53eb5e5");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Test The Model (Other Cells may need to be ran before this cell)

import tensorflow as tf
import numpy as np

from keras.saving import load_model
from keras import Model

import shutil
import os

def round(n: float):
    if n >= 0.5:
        return 1.0
    else:
        return 0.0

print(tf.version.VERSION)

test_labels, test_images, filenames = load('test')

print("Dataset Loaded Successfully")

model: Model = load_model('models/initial.keras')

print("Model Loaded Successfully")

print("Creating directory incorrect/")

try:
    shutil.rmtree("incorrect/")
except:
    pass

os.mkdir("incorrect/")

predictions = model.predict(test_images)

for i in range(0, test_labels.__len__()):
    prediction = 0.0
    if predictions[i] >= 0.5:
        prediction = 1.0

    if prediction == test_labels[i]:
        print("🟢 " + filenames[i] + ", " + str(prediction))
    else:
        print("❌ " + filenames[i] + ", " + str(prediction))
        shutil.copy(filenames[i], "incorrect/")
        
loss, acc = model.evaluate(test_images, test_labels)

print(f'Overall Accuracy: {acc}')
# Out:
# 2.15.0
# Dataset Loaded Successfully
# Model Loaded Successfully
# Creating directory incorrect/
# 3/3 [==============================] - 0s 12ms/step
# 🟢 data/test/stop/317.png, 1.0
# 🟢 data/test/stop/321.png, 1.0
# 🟢 data/test/stop/339.png, 1.0
# 🟢 data/test/stop/312.png, 1.0
# 🟢 data/test/stop/331.png, 1.0
# 🟢 data/test/stop/328.png, 1.0
# 🟢 data/test/stop/322.png, 1.0
# 🟢 data/test/stop/342.png, 1.0
# 🟢 data/test/stop/338.png, 1.0
# 🟢 data/test/stop/345.png, 1.0
# 🟢 data/test/stop/314.png, 1.0
# 🟢 data/test/stop/324.png, 1.0
# 🟢 data/test/stop/313.png, 1.0
# 🟢 data/test/stop/333.png, 1.0
# 🟢 data/test/stop/325.png, 1.0
# 🟢 data/test/stop/332.png, 1.0
# 🟢 data/test/stop/326.png, 1.0
# 🟢 data/test/stop/329.png, 1.0
# 🟢 data/test/stop/320.png, 1.0
# 🟢 data/test/stop/337.png, 1.0
# 🟢 data/test/stop/343.png, 1.0
# 🟢 data/test/stop/318.png, 1.0
# 🟢 data/test/stop/336.png, 1.0
# 🟢 data/test/stop/348.png, 1.0
# 🟢 data/test/stop/327.png, 1.0
# 🟢 data/test/stop/319.png, 1.0
# 🟢 data/test/stop/350.png, 1.0
# 🟢 data/test/stop/341.png, 1.0
# 🟢 data/test/stop/330.png, 1.0
# ❌ data/test/stop/340.png, 0.0
# 🟢 data/test/stop/316.png, 1.0
# 🟢 data/test/stop/349.png, 1.0
# ❌ data/test/stop/311.png, 0.0
# 🟢 data/test/stop/344.png, 1.0
# 🟢 data/test/stop/315.png, 1.0
# 🟢 data/test/stop/334.png, 1.0
# 🟢 data/test/stop/346.png, 1.0
# 🟢 data/test/stop/335.png, 1.0
# 🟢 data/test/stop/347.png, 1.0
# 🟢 data/test/stop/323.png, 1.0
# ❌ data/test/no_stop/374.png, 1.0
# 🟢 data/test/no_stop/354.png, 0.0
# 🟢 data/test/no_stop/375.png, 0.0
# 🟢 data/test/no_stop/367.png, 0.0
# 🟢 data/test/no_stop/361.png, 0.0
# 🟢 data/test/no_stop/371.png, 0.0
# 🟢 data/test/no_stop/355.png, 0.0
# 🟢 data/test/no_stop/342.png, 0.0
# 🟢 data/test/no_stop/345.png, 0.0
# ❌ data/test/no_stop/365.png, 1.0
# 🟢 data/test/no_stop/356.png, 0.0
# 🟢 data/test/no_stop/364.png, 0.0
# 🟢 data/test/no_stop/370.png, 0.0
# 🟢 data/test/no_stop/343.png, 0.0
# 🟢 data/test/no_stop/373.png, 0.0
# 🟢 data/test/no_stop/378.png, 0.0
# 🟢 data/test/no_stop/352.png, 0.0
# 🟢 data/test/no_stop/380.png, 0.0
# 🟢 data/test/no_stop/348.png, 0.0
# 🟢 data/test/no_stop/357.png, 0.0
# 🟢 data/test/no_stop/358.png, 0.0
# 🟢 data/test/no_stop/350.png, 0.0
# 🟢 data/test/no_stop/351.png, 0.0
# 🟢 data/test/no_stop/341.png, 0.0
# 🟢 data/test/no_stop/362.png, 0.0
# 🟢 data/test/no_stop/340.png, 0.0
# 🟢 data/test/no_stop/363.png, 0.0
# 🟢 data/test/no_stop/359.png, 0.0
# 🟢 data/test/no_stop/349.png, 0.0
# 🟢 data/test/no_stop/379.png, 0.0
# 🟢 data/test/no_stop/344.png, 0.0
# 🟢 data/test/no_stop/369.png, 0.0
# 🟢 data/test/no_stop/353.png, 0.0
# 🟢 data/test/no_stop/366.png, 0.0
# 🟢 data/test/no_stop/360.png, 0.0
# 🟢 data/test/no_stop/346.png, 0.0
# 🟢 data/test/no_stop/347.png, 0.0
# 🟢 data/test/no_stop/376.png, 0.0
# 🟢 data/test/no_stop/368.png, 0.0
# 🟢 data/test/no_stop/372.png, 0.0
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4133 - accuracy: 0.9500
# Overall Accuracy: 0.949999988079071

# %% [markdown]
# # The Model
#
# ## Attempt 1:
#
# Model trains well and achieves 98-100% accuracy, but overfits. Low test accuracy.
#
# - 224x224x3 input,
# - repeat 4:
#     - Conv2D(filter=16, ksize=(3,3), actv='relu')
#     - MaxPool2D(pool_size=(2,2), strides=2)
# - Flatten
# - Batch Norm
# - Dense(128, actv='relu')
# - Dropout(rate=.5)
# - Dense(1, activation='sigmoid')

# %%
# Model Builder Function

import tensorflow as tf
from keras import Input
from keras.models import Sequential
from keras.layers import *

def create_model():
    model = Sequential()

    # All Inputs must be the same size.
    IMG_SIZE=244
    model.add(Input(shape=(IMG_SIZE,IMG_SIZE,3)))

    # Preprocessing
    model.add(RandomRotation(1.))
    model.add(RandomFlip())

    # 4x kernel=(3,3) filters=12 conv
    for _ in range(0, 5):
        model.add(Conv2D(filters=12, kernel_size=(3,3), activation='relu'))
        model.add(MaxPool2D(pool_size=(2,2), strides=2))

    model.add(Flatten())
    model.add(Dropout(.25))
    model.add(BatchNormalization())
    model.add(Dense(8, activation='sigmoid', kernel_regularizer='l2'))
    model.add(Dropout(.25))
    model.add(Dense(1, activation='sigmoid', kernel_regularizer='l2'))

    return model

# %%
from pathlib import Path

import tensorflow as tf
from keras.preprocessing.image import *

import numpy as np
import PIL

IMG_SIZE=244

def load(name: str):
    labels = []
    images = []
    names = []

    for path in Path('data/' + name + '/stop/').glob('*'):
        path = str(path)
        img = tf.io.read_file(path)
        img = tf.io.decode_image(img, channels=3)
        img = smart_resize(img, size=(IMG_SIZE,IMG_SIZE))
        img = img_to_array(img)
        img = img / 255.0
        labels.append(1.0)
        images.append(img)
        names.append(path)

    for path in Path('data/' + name + '/no_stop/').glob('*'):
        path = str(path)
        img = tf.io.read_file(path)
        img = tf.io.decode_image(img, channels=3)
        img = smart_resize(img, size=(IMG_SIZE,IMG_SIZE))
        img = img_to_array(img)
        img = img / 255.0
        labels.append(0.0)
        images.append(img)
        names.append(path)

    return np.array(labels), np.array(images), names
